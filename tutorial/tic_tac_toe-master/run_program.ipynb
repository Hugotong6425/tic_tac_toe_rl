# %%
from game import Game
from dqn import QNetwork, ReplayMemory
from main import train, play

# %%
train()
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/hugo/Desktop/self_learning/tic_tac_toe_rl/tutorial/tic_tac_toe-master/dqn.py:19: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# From /home/hugo/Desktop/self_learning/tic_tac_toe_rl/tutorial/tic_tac_toe-master/dqn.py:19: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# ...

# %%
play()
# Out:
# INFO:tensorflow:Restoring parameters from ./models/q.ckpt
# Restoring parameters from ./models/q.ckpt
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/envs/general_rl/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#
# ~/anaconda3/envs/general_rl/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#
# ~/anaconda3/envs/general_rl/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
# ...
