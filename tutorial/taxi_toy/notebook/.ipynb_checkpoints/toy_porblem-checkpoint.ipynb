# %%
import gym
from time import sleep
from IPython.display import clear_output


# Printing all the possible actions, states, rewards.
def renderFrames(frames):
    for i, frame in enumerate(frames):
        clear_output(wait=True)
        print(frame['frame'].getvalue())
        #print("Timestep: %s" % i + 1)
        print("State: %s" % frame['state'])
        print("Action: %s" % frame['action'])
        print("Reward: %s" % frame['reward'])
        sleep(.1)
        
        
# Creating thr env
env = gym.make("Taxi-v2").env

env.s = 328


# Setting the number of iterations, penalties and reward to zero,
epochs = 0
penalties, reward = 0, 0

frames = []

done = False

while not done:
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    
    print('state: %s' % state)
    print('reward: %s' % reward)
    print('done: %s' % done)
    print('info: %s\n' % info)
    
    if reward == -10:
        penalties += 1

    # Put each rendered frame into the dictionary for animation
    frames.append({
        'frame': env.render(mode='ansi'),
        'state': state,
        'action': action,
        'reward': reward
    }
    )

    epochs += 1

print("Timesteps taken: {}".format(epochs))
print("Penalties incurred: {}".format(penalties))

        
#renderFrames(frames)
# Out:
# state: 328
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 428
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 328
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 208
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 448
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 348
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 268
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 288
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 388
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 288
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 188
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 88
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 88
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 68
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 48
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 68
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 48
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 148
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 208
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 148
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 268
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 268
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 368
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 368
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 268
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 368
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 388
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 388
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 368
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 388
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 368
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 388
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 288
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 288
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 268
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 248
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 228
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 148
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 28
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 8
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 128
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 108
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 208
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 216
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 208
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 208
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 308
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 408
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 416
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 316
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 216
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 116
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 16
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 16
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 36
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 36
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 36
# reward: -10
# done: False
# info: {'prob': 1.0}
#
# state: 16
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 16
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 36
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 16
# reward: -1
# done: False
# info: {'prob': 1.0}
#
# state: 16
# reward: 20
# done: True
# info: {'prob': 1.0}
#
# Timesteps taken: 256
# Penalties incurred: 58

# %%
# Creating thr env
env = gym.make("Taxi-v2").env

env.reward_range
# Out:
# (-inf, inf)

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.action_space.dtype
# Out:
# dtype('int64')

# %%
print(env.action_space)
print(env.observation_space.sample())
# Out:
# Discrete(6)
# 61

# %%
env.close()

# %%
env.reset
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-a2213dbf3e4f> in <module>()
# ----> 1 env.decode()
#
# TypeError: decode() missing 1 required positional argument: 'i'

# %%
env.render()
