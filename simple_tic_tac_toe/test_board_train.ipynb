# %%
# %load_ext autoreload
# %autoreload 2

# %%
from py_files.board import Board
from py_files.player import Q_player, Random_player, Human

# %%
p1_config = {'player_type':'random'}
p2_config = {'player_type':'q_player', 'hidden_layers_size':[20,10,10]}

win_reward = 1
lose_reward = -1
draw_reward = 0

test_board = Board(p1_config=p1_config, p2_config=p2_config, 
                   win_reward=win_reward, lose_reward=lose_reward, 
                   draw_reward=draw_reward)

# %%
test_board.play()
# Out:
# --------------------------------------------------
#
# current player id: 1
#
# current player name: q player
#
# Board:
#
# O |   |
# ---------
#   |   |
# ---------
#   |   |
#
# is_terminal_state:
# False
#
# --------------------------------------------------
#
# current player id: -1
#
# current player name: random player
#
# Board:
#
# O |   |
# ---------
# X |   |
# ---------
#   |   |
#
# is_terminal_state:
# False
#
# --------------------------------------------------
#
# current player id: 1
#
# current player name: q player
#
# Board:
#
# O |   | O
# ---------
# X |   |
# ---------
#   |   |
#
# is_terminal_state:
# False
#
# --------------------------------------------------
#
# current player id: -1
#
# current player name: random player
#
# Board:
#
# O |   | O
# ---------
# X |   |
# ---------
#   | X |
#
# is_terminal_state:
# False
#
# --------------------------------------------------
#
# current player id: 1
#
# current player name: q player
#
# Board:
#
# O |   | O
# ---------
# X | O |
# ---------
#   | X |
#
# is_terminal_state:
# False
#
# --------------------------------------------------
#
# current player id: -1
#
# current player name: random player
#
# Board:
#
# O |   | O
# ---------
# X | O |
# ---------
#   | X | X
#
# is_terminal_state:
# False
#
# --------------------------------------------------
#
# current player id: 1
#
# current player name: q player
#
# Board:
#
# O |   | O
# ---------
# X | O |
# ---------
# O | X | X
#
# is_terminal_state:
# True
#
# Game Over!
